# %% [markdown]
# # Upload sequencing data to SRA
# This Python Jupyter notebook uploads the sequencing data to the NIH [Sequence Read Archive](https://www.ncbi.nlm.nih.gov/sra), or SRA.

# %% [markdown]
# ## Create BioProject and BioSamples
# The first step was done manually to create the BioProject and BioSamples.
# Note that for new future uploads related to the RBD DMS, you may be able to use the existing BioProject, but since this is the first entries in these project I needed to create a new BioProject.
#
# To create these, I went to the [Sequence Read Archive](https://www.ncbi.nlm.nih.gov/sra) and signed in using the box at the upper right of the webpage, and then went to the [SRA Submission Portal](https://submit.ncbi.nlm.nih.gov/subs/sra/).
# I then manually completed the first five steps, which define the project and samples.

# %% [markdown]
# ## Create submission sheet
# The sixth step is to create the submission sheet in `*.tsv` format, which is done by the following code.
#
# First, import Python modules:

# %%
import os

import natsort

import pandas as pd

import yaml

# %% [markdown]
# Read the configuration for the analysis:

# %%
with open('../config.yaml') as f:
    config = yaml.safe_load(f)

# %% [markdown]
# Read the PacBio runs:

# %%
pacbio_runs_file = os.path.join('../', config['pacbio_runs'])

print(f"Reading PacBio runs from {pacbio_runs_file}")

pacbio_runs = (
    pd.read_csv(pacbio_runs_file)
    .assign(ccs_file=lambda x: f"../{config['ccs_dir']}/" + x['library'] + '_' + x['run'] + '_ccs.fastq.gz')
    )

pacbio_runs.head()
# Out:
# Reading PacBio runs from ../data/PacBio_runs.csv
#   library       run                                           subreads  \
# 0    lib1  200415_A  /fh/fast/bloom_j/SR/ngs/pacbio/200415_TylerSta...
# 1    lib1  200415_B  /fh/fast/bloom_j/SR/ngs/pacbio/200415_TylerSta...
# 2    lib2  200415_A  /fh/fast/bloom_j/SR/ngs/pacbio/200415_TylerSta...
# 3    lib2  200415_B  /fh/fast/bloom_j/SR/ngs/pacbio/200415_TylerSta...
#
#                                     ccs_file
# 0  ../results/ccs/lib1_200415_A_ccs.fastq.gz
# 1  ../results/ccs/lib1_200415_B_ccs.fastq.gz
# 2  ../results/ccs/lib2_200415_A_ccs.fastq.gz
# 3  ../results/ccs/lib2_200415_B_ccs.fastq.gz

# %% [markdown]
# Next make submission entries for the PacBio CCSs:

# %%
pacbio_submissions = (
    pacbio_runs
    .assign(
        sample_name='PacBio_CCSs',  # BioSample created in SRA wizard
        library_ID=lambda x: x['library'] + '_PacBio_CCSs',  # unique library ID
        title='PacBio CCSs linking variants to barcodes for SARS-CoV-2 RBD deep mutational scanning',
        library_strategy='Synthetic-Long-Read',
        library_source='SYNTHETIC',
        library_selection='Restriction Digest',
        library_layout='single',
        platform='PACBIO_SMRT',
        instrument_model='PacBio Sequel',
        design_description='Restriction digest of plasmids carrying barcoded RBD variants',
        filetype='fastq',
        filename_fullpath=lambda x: x['ccs_file'],      
        )
    .drop(columns=pacbio_runs.columns)
    )

pacbio_submissions.head()
# Out:
#    sample_name        library_id  \
# 0  PacBio_CCSs  lib1_PacBio_CCSs
# 1  PacBio_CCSs  lib1_PacBio_CCSs
# 2  PacBio_CCSs  lib2_PacBio_CCSs
# 3  PacBio_CCSs  lib2_PacBio_CCSs
#
#                                                title     library_strategy  \
# 0  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 1  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 2  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 3  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
#
#   library_source   library_selection library_layout     platform  \
# 0      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 1      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 2      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 3      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
#
#   instrument_model                                 design_description  \
# 0    PacBio Sequel  Restriction digest of plasmids carrying barcod...
# 1    PacBio Sequel  Restriction digest of plasmids carrying barcod...
# 2    PacBio Sequel  Restriction digest of plasmids carrying barcod...
# 3    PacBio Sequel  Restriction digest of plasmids carrying barcod...
#
#   filetype                          filename_fullpath
# 0    fastq  ../results/ccs/lib1_200415_A_ccs.fastq.gz
# 1    fastq  ../results/ccs/lib1_200415_B_ccs.fastq.gz
# 2    fastq  ../results/ccs/lib2_200415_A_ccs.fastq.gz
# 3    fastq  ../results/ccs/lib2_200415_B_ccs.fastq.gz

# %% [markdown]
# Read the Illumina runs:

# %%
illumina_runs_file = os.path.join('../', config['barcode_runs'])

print(f"Reading Illumina runs from {illumina_runs_file}")

illumina_runs = pd.read_csv(illumina_runs_file)

illumina_runs.head()
# Out:
# Reading Illumina runs from ../data/barcode_runs.csv
#   library        sample sample_type  sort_bin  concentration    date  \
# 0    lib1  SortSeq_bin1     SortSeq         1            NaN  200416
# 1    lib1  SortSeq_bin2     SortSeq         2            NaN  200416
# 2    lib1  SortSeq_bin3     SortSeq         3            NaN  200416
# 3    lib1  SortSeq_bin4     SortSeq         4            NaN  200416
# 4    lib2  SortSeq_bin1     SortSeq         1            NaN  200416
#
#    number_cells                                                 R1
# 0       6600000  /shared/ngs/illumina/tstarr/200427_D00300_0952...
# 1       3060000  /shared/ngs/illumina/tstarr/200427_D00300_0952...
# 2       2511000  /shared/ngs/illumina/tstarr/200427_D00300_0952...
# 3       2992000  /shared/ngs/illumina/tstarr/200427_D00300_0952...
# 4       6420000  /shared/ngs/illumina/tstarr/200427_D00300_0953...

# %% [markdown]
# Next make submission entries for Illumina data:

# %%
illumina_submissions = (
    illumina_runs
    .assign(
        sample_name=lambda x: x['sample_type'].map({'SortSeq': 'expression_barcodes',
                                                    'TiteSeq': 'hACE2_binding_barcodes'}),
        library_ID=lambda x: x['library'] + '_' + x['sample'],
        title=lambda x: 'SARS-CoV-2 RBD deep mutational scanning Illumina barcode sequencing for ' + x['sample'],
        library_strategy='AMPLICON',
        library_source='SYNTHETIC',
        library_selection='PCR',
        library_layout='single',
        platform='ILLUMINA',
        instrument_model='Illumina HiSeq 2500',
        design_description='PCR of barcodes from RBD variants',
        filetype='fastq',
        filename_fullpath=lambda x: x['R1'].str.split(';'),       
        )
    .explode('filename_fullpath')
    .assign(filename_fullpath=lambda x: x['filename_fullpath'].str.strip())
    .drop(columns=illumina_runs.columns)
    .reset_index(drop=True)
    )

illumina_submissions.head()
# Out:
#            sample_name         library_id  \
# 0  expression_barcodes  lib1_SortSeq_bin1
# 1  expression_barcodes  lib1_SortSeq_bin1
# 2  expression_barcodes  lib1_SortSeq_bin1
# 3  expression_barcodes  lib1_SortSeq_bin1
# 4  expression_barcodes  lib1_SortSeq_bin1
#
#                                                title library_strategy  \
# 0  SARS-CoV-2 RBD deep mutational scanning Illumi...         AMPLICON
# 1  SARS-CoV-2 RBD deep mutational scanning Illumi...         AMPLICON
# 2  SARS-CoV-2 RBD deep mutational scanning Illumi...         AMPLICON
# 3  SARS-CoV-2 RBD deep mutational scanning Illumi...         AMPLICON
# 4  SARS-CoV-2 RBD deep mutational scanning Illumi...         AMPLICON
#
#   library_source library_selection library_layout  platform  \
# 0      SYNTHETIC               PCR         single  ILLUMINA
# 1      SYNTHETIC               PCR         single  ILLUMINA
# 2      SYNTHETIC               PCR         single  ILLUMINA
# 3      SYNTHETIC               PCR         single  ILLUMINA
# 4      SYNTHETIC               PCR         single  ILLUMINA
#
#       instrument_model                 design_description filetype  \
# 0  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 1  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 2  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 3  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 4  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
#
#                                    filename_fullpath
# 0  /shared/ngs/illumina/tstarr/200427_D00300_0952...
# 1  /fh/fast/bloom_j/SR/ngs/illumina/tstarr/200427...
# 2  /fh/fast/bloom_j/SR/ngs/illumina/tstarr/200427...
# 3  /fh/fast/bloom_j/SR/ngs/illumina/tstarr/200427...
# 4  /fh/fast/bloom_j/SR/ngs/illumina/tstarr/200427...

# %% [markdown]
# Now concatenate the PacBio and Illumina submissions into tidy format (one line per file), make sure all the files exist, and also make short name versions of them that lack the path:

# %%
submissions_tidy = (
    pd.concat([pacbio_submissions, illumina_submissions], ignore_index=True)
    .assign(file_exists=lambda x: x['filename_fullpath'].map(os.path.isfile),
            filename=lambda x: x['filename_fullpath'].map(os.path.basename),
            )
    )

assert submissions_tidy['file_exists'].all(), submissions_tidy.query('file_exists == False')

submissions_tidy.head()
# Out:
#            sample_name         library_id  \
# 0          PacBio_CCSs   lib1_PacBio_CCSs
# 1          PacBio_CCSs   lib1_PacBio_CCSs
# 2          PacBio_CCSs   lib2_PacBio_CCSs
# 3          PacBio_CCSs   lib2_PacBio_CCSs
# 4  expression_barcodes  lib1_SortSeq_bin1
#
#                                                title     library_strategy  \
# 0  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 1  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 2  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 3  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 4  SARS-CoV-2 RBD deep mutational scanning Illumi...             AMPLICON
#
#   library_source   library_selection library_layout     platform  \
# 0      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 1      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 2      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 3      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 4      SYNTHETIC                 PCR         single     ILLUMINA
#
#       instrument_model                                 design_description  \
# 0        PacBio Sequel  Restriction digest of plasmids carrying barcod...
# 1        PacBio Sequel  Restriction digest of plasmids carrying barcod...
# 2        PacBio Sequel  Restriction digest of plasmids carrying barcod...
# 3        PacBio Sequel  Restriction digest of plasmids carrying barcod...
# 4  Illumina HiSeq 2500                  PCR of barcodes from RBD variants
#
#   filetype                                  filename_fullpath  file_exists  \
# 0    fastq          ../results/ccs/lib1_200415_A_ccs.fastq.gz         True
# 1    fastq          ../results/ccs/lib1_200415_B_ccs.fastq.gz         True
# 2    fastq          ../results/ccs/lib2_200415_A_ccs.fastq.gz         True
# 3    fastq          ../results/ccs/lib2_200415_B_ccs.fastq.gz         True
# 4    fastq  /shared/ngs/illumina/tstarr/200427_D00300_0952...         True
#
#                                             filename
# 0                         lib1_200415_A_ccs.fastq.gz
# 1                         lib1_200415_B_ccs.fastq.gz
# 2                         lib2_200415_A_ccs.fastq.gz
# 3                         lib2_200415_B_ccs.fastq.gz
# 4  200416_lib1_FITCbin1_TGGAACAA_L001_R1_001.fast...

# %% [markdown]
# For the actual submission, we need a "wide" data frame that for each unique `sample_name` / `library_ID` gives all of the files each in different columns.
# These should be files without the full path.
#
# First, look at how many files there are for each sample / library:

# %%
(submissions_tidy
 .groupby(['sample_name', 'library_ID'])
 .aggregate(n_files=pd.NamedAgg('filename_fullpath', 'count'))
 .sort_values('n_files', ascending=False)
 .reset_index()
 )
# Out:
#                 sample_name            library_id  n_files
# 0       expression_barcodes     lib1_SortSeq_bin1       10
# 1       expression_barcodes     lib2_SortSeq_bin1        8
# 2    hACE2_binding_barcodes  lib1_TiteSeq_12_bin1        6
# 3    hACE2_binding_barcodes  lib2_TiteSeq_16_bin1        6
# 4    hACE2_binding_barcodes  lib2_TiteSeq_13_bin1        6
# ..                      ...                   ...      ...
# 133  hACE2_binding_barcodes  lib1_TiteSeq_10_bin4        2
# 134  hACE2_binding_barcodes  lib1_TiteSeq_10_bin3        2
# 135  hACE2_binding_barcodes  lib1_TiteSeq_10_bin2        2
# 136  hACE2_binding_barcodes  lib2_TiteSeq_16_bin4        2
# 137  hACE2_binding_barcodes  lib2_TiteSeq_04_bin3        1
#
# [138 rows x 3 columns]

# %% [markdown]
# Now make the wide submission data frame.
# Note we keep only the filename column with the path lacking the full directory information:

# %%
submissions_wide = (
    submissions_tidy
    .assign(
        filename_count=lambda x: x.groupby(['sample_name', 'library_ID'])['filename'].cumcount() + 1,
        filename_col=lambda x: 'filename' + x['filename_count'].map(lambda c: str(c) if c > 1 else '')
        )
    .pivot(
        index='library_ID',
        columns='filename_col',
        values='filename',
        )
    )

submissions_wide = (
    submissions_tidy
    .drop(columns=['filename_fullpath', 'file_exists', 'filename'])
    .drop_duplicates()
    .merge(submissions_wide[natsort.natsorted(submissions_wide.columns)],
           on='library_ID',
           validate='one_to_one',
           )
    )

submissions_wide
# Out:
#                 sample_name            library_id  \
# 0               PacBio_CCSs      lib1_PacBio_CCSs
# 1               PacBio_CCSs      lib2_PacBio_CCSs
# 2       expression_barcodes     lib1_SortSeq_bin1
# 3       expression_barcodes     lib1_SortSeq_bin2
# 4       expression_barcodes     lib1_SortSeq_bin3
# ..                      ...                   ...
# 133  hACE2_binding_barcodes  lib2_TiteSeq_15_bin4
# 134  hACE2_binding_barcodes  lib2_TiteSeq_16_bin1
# 135  hACE2_binding_barcodes  lib2_TiteSeq_16_bin2
# 136  hACE2_binding_barcodes  lib2_TiteSeq_16_bin3
# 137  hACE2_binding_barcodes  lib2_TiteSeq_16_bin4
#
#                                                  title     library_strategy  \
# 0    PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 1    PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 2    SARS-CoV-2 RBD deep mutational scanning Illumi...             AMPLICON
# 3    SARS-CoV-2 RBD deep mutational scanning Illumi...             AMPLICON
# 4    SARS-CoV-2 RBD deep mutational scanning Illumi...             AMPLICON
# ..                                                 ...                  ...
# 133  SARS-CoV-2 RBD deep mutational scanning Illumi...             AMPLICON
# 134  SARS-CoV-2 RBD deep mutational scanning Illumi...             AMPLICON
# 135  SARS-CoV-2 RBD deep mutational scanning Illumi...             AMPLICON
# 136  SARS-CoV-2 RBD deep mutational scanning Illumi...             AMPLICON
# 137  SARS-CoV-2 RBD deep mutational scanning Illumi...             AMPLICON
#
#     library_source   library_selection library_layout     platform  \
# 0        SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 1        SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 2        SYNTHETIC                 PCR         single     ILLUMINA
# 3        SYNTHETIC                 PCR         single     ILLUMINA
# 4        SYNTHETIC                 PCR         single     ILLUMINA
# ..             ...                 ...            ...          ...
# 133      SYNTHETIC                 PCR         single     ILLUMINA
# 134      SYNTHETIC                 PCR         single     ILLUMINA
# 135      SYNTHETIC                 PCR         single     ILLUMINA
# 136      SYNTHETIC                 PCR         single     ILLUMINA
# 137      SYNTHETIC                 PCR         single     ILLUMINA
#
#         instrument_model                                 design_description  \
# 0          PacBio Sequel  Restriction digest of plasmids carrying barcod...
# 1          PacBio Sequel  Restriction digest of plasmids carrying barcod...
# 2    Illumina HiSeq 2500                  PCR of barcodes from RBD variants
# 3    Illumina HiSeq 2500                  PCR of barcodes from RBD variants
# 4    Illumina HiSeq 2500                  PCR of barcodes from RBD variants
# ..                   ...                                                ...
# 133  Illumina HiSeq 2500                  PCR of barcodes from RBD variants
# 134  Illumina HiSeq 2500                  PCR of barcodes from RBD variants
# 135  Illumina HiSeq 2500                  PCR of barcodes from RBD variants
# 136  Illumina HiSeq 2500                  PCR of barcodes from RBD variants
# 137  Illumina HiSeq 2500                  PCR of barcodes from RBD variants
#
#      ...                                           filename  \
# 0    ...                         lib1_200415_A_ccs.fastq.gz
# 1    ...                         lib2_200415_A_ccs.fastq.gz
# 2    ...  200416_lib1_FITCbin1_TGGAACAA_L001_R1_001.fast...
# 3    ...  200416_lib1_FITCbin2_TGGCTTCA_L001_R1_001.fast...
# 4    ...  200416_lib1_FITCbin3_TGGTGGTA_L001_R1_001.fast...
# ..   ...                                                ...
# 133  ...        200422_s15-b4_TAGGATGA_L001_R1_001.fastq.gz
# 134  ...        200422_s16-b1_TATCAGCA_L001_R1_001.fastq.gz
# 135  ...        200422_s16-b2_TCCGTCTA_L001_R1_001.fastq.gz
# 136  ...        200422_s16-b3_TCTTCACA_L001_R1_001.fastq.gz
# 137  ...        200422_s16-b4_TGAAGAGA_L001_R1_001.fastq.gz
#
#                                              filename2  \
# 0                           lib1_200415_B_ccs.fastq.gz
# 1                           lib2_200415_B_ccs.fastq.gz
# 2    200416_lib1_FITCbin1_TGGAACAA_L001_R1_002.fast...
# 3    200416_lib1_FITCbin2_TGGCTTCA_L001_R1_002.fast...
# 4    200416_lib1_FITCbin3_TGGTGGTA_L001_R1_002.fast...
# ..                                                 ...
# 133        200422_s15-b4_TAGGATGA_L002_R1_001.fastq.gz
# 134        200422_s16-b1_TATCAGCA_L001_R1_002.fastq.gz
# 135        200422_s16-b2_TCCGTCTA_L002_R1_001.fastq.gz
# 136        200422_s16-b3_TCTTCACA_L002_R1_001.fastq.gz
# 137        200422_s16-b4_TGAAGAGA_L002_R1_001.fastq.gz
#
#                                              filename3  \
# 0                                                  NaN
# 1                                                  NaN
# 2    200416_lib1_FITCbin1_TGGAACAA_L001_R1_003.fast...
# 3    200416_lib1_FITCbin2_TGGCTTCA_L002_R1_001.fast...
# 4    200416_lib1_FITCbin3_TGGTGGTA_L002_R1_001.fast...
# ..                                                 ...
# 133                                                NaN
# 134        200422_s16-b1_TATCAGCA_L001_R1_003.fastq.gz
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                              filename4  \
# 0                                                  NaN
# 1                                                  NaN
# 2    200416_lib1_FITCbin1_TGGAACAA_L001_R1_004.fast...
# 3    200416_lib1_FITCbin2_TGGCTTCA_L002_R1_002.fast...
# 4    200416_lib1_FITCbin3_TGGTGGTA_L002_R1_002.fast...
# ..                                                 ...
# 133                                                NaN
# 134        200422_s16-b1_TATCAGCA_L002_R1_001.fastq.gz
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                              filename5  \
# 0                                                  NaN
# 1                                                  NaN
# 2    200416_lib1_FITCbin1_TGGAACAA_L001_R1_005.fast...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134        200422_s16-b1_TATCAGCA_L002_R1_002.fastq.gz
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                              filename6  \
# 0                                                  NaN
# 1                                                  NaN
# 2    200416_lib1_FITCbin1_TGGAACAA_L002_R1_001.fast...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134        200422_s16-b1_TATCAGCA_L002_R1_003.fastq.gz
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                              filename7  \
# 0                                                  NaN
# 1                                                  NaN
# 2    200416_lib1_FITCbin1_TGGAACAA_L002_R1_002.fast...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                              filename8  \
# 0                                                  NaN
# 1                                                  NaN
# 2    200416_lib1_FITCbin1_TGGAACAA_L002_R1_003.fast...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                              filename9  \
# 0                                                  NaN
# 1                                                  NaN
# 2    200416_lib1_FITCbin1_TGGAACAA_L002_R1_004.fast...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                             filename10
# 0                                                  NaN
# 1                                                  NaN
# 2    200416_lib1_FITCbin1_TGGAACAA_L002_R1_005.fast...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
# [138 rows x 21 columns]

# %% [markdown]
# Now write the wide submissions data frame to a `*.tsv` file:

# %%
submissions_spreadsheet = 'SRA_submission_spreadsheet.tsv'

submissions_wide.to_csv(submissions_spreadsheet, sep='\t', index=False)

# %% [markdown]
# This submission sheet was then manually uploaded in Step 6 of the SRA submission wizard (*SRA metadata*).
